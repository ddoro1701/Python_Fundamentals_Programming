# %%
upper_limit = int(input("Enter an upper limit: "))
# Out:
# Enter an upper limit:  6

# %%
even_sum = 0

# %%
for number in range(2, upper_limit, 2):
    even_sum += number

# %%
print(f"The sum of even numbers from 2 to {upper_limit} is {even_sum}")
# Out:
# The sum of even numbers from 2 to 6 is 6
