# %%
#create a list of names
names = ["Alice", "Bob","Eve", "Charlie", "David"]

#Use the built-in sort() methodto sort the list
names.sort()

# %%
#print the sorted list
print("Sorted List of names")
for name in names:
    print(name)
# Out:
# Sorted List of names
# Alice
# Bob
# Charlie
# David
# Eve
