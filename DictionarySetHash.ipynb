# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
# putting keys and value to a set
capitals = {'United States': 'Washington DC', 'France': 'Paris', 'Italy': 'Rome'}

# %%
capitals
# Out:
# {'United States': 'Washington DC', 'France': 'Paris', 'Italy': 'Rome'}

# %%
capitals['Italy']
# Out:
# 'Rome'

# %%
capitals['Spain'] = 'Madrid'

# %%
capitals
# Out:
# {'United States': 'Washington DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid'}

# %%
capitals['Germany']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 capitals['Germany']
#
# KeyError: 'Germany'

# %%
## no more Germany, # error message

# %%
#check if there is Germany in capitals? Italy? With Boolean

# %%
'Germany' in capitals, 'Italy' in capitals
# Out:
# (False, True)

# %%
# add in more capital and assign to a set
morecapitals = {'Germany': 'Berlin', 'United Kingdom': 'London'}

# %%
capitals + morecapitals
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 capitals + morecapitals
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
#capitals updated
capitals.update(morecapitals)

# %%
capitals
# Out:
# {'United States': 'Washington DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'Germany': 'Berlin',
#  'United Kingdom': 'London'}

# %%
del capitals['United Kingdom']

# %%
capitals
# Out:
# {'United States': 'Washington DC',
#  'France': 'Paris',
#  'Italy': 'Rome',
#  'Spain': 'Madrid',
#  'Germany': 'Berlin'}

# %%
birthdays = {(7, 15): 'Michelle', (3,14): 'Albert'}

# %%
birthdays[(7,15)]
# Out:
# 'Michelle'

# %%
#The hash() method returns the hash value of an object if it has one
# Hash values are just integers that are used to compare dictionary keys during a dictionary look quickly
hash((7,15))
# Out:
# -2471369287409462312

# %%
{}
# Out:
# {}

# %%
len({})
# Out:
# 0

# %%
for country in capitals:
    print(country)
# Out:
# United States
# France
# Italy
# Spain
# Germany

# %%
capitals.keys()
# Out:
# dict_keys(['United States', 'France', 'Italy', 'Spain', 'Germany'])

# %%
list(capitals.keys())
# Out:
# ['United States', 'France', 'Italy', 'Spain', 'Germany']

# %%
for _ in capitals.values():
    print(_)
# Out:
# Washington DC
# Paris
# Rome
# Madrid
# Berlin

# %%
#call the key and the values as items
for country, capital in capitals.items():
    print(country, capital)
# Out:
# United States Washington DC
# France Paris
# Italy Rome
# Spain Madrid
# Germany Berlin

# %%
continents = {'America','Europe', 'Asia', 'Oceania','Africa', 'Africa'}

# %%
# take bot on the arrangment
continents
# Out:
# {'Africa', 'America', 'Asia', 'Europe', 'Oceania'}

# %%
'Africa' in continents
# Out:
# True

# %%
continents.add('Antarctica')

# %%
continents
# Out:
# {'Africa', 'America', 'Antarctica', 'Asia', 'Europe', 'Oceania'}

# %%
continents.remove('Antarctica')

# %%
continents
# Out:
# {'Africa', 'America', 'Asia', 'Europe', 'Oceania'}

# %%
for c in continents:
    print(c)
# Out:
# Europe
# Africa
# Asia
# Oceania
# America
