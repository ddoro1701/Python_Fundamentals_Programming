# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
nephews = ["Huey", "Dewey", "Louie"]

# %%
nephews
# Out:
# ['Huey', 'Dewey', 'Louie']

# %%
len(nephews)
# Out:
# 3

# %%
nephews
# Out:
# ['Huey', 'Dewey', 'Louie']

# %%
len(nephews)
# Out:
# 3

# %%
nephews[1]
# Out:
# 'Dewey'

# %%
nephews[2]
# Out:
# 'Louie'

# %%
nephews[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 nephews[3]
#
# IndexError: list index out of range

# %%
nephews[-1], nephews[-2]
# Out:
# ('Louie', 'Dewey')

# %%
#range
for i in range(3):
    nephews[i] = nephews[i] + ' Duck'

# %%
nephews
# Out:
# ['Huey Duck', 'Dewey Duck', 'Louie Duck']

# %%
#Lets try put list and tuple and text
mix_it_up = [1, [2,3], 'alpha']

# %%
mix_it_up
# Out:
# [1, [2, 3], 'alpha']

# %%
nephews.append('April Duck')

# %%
nephews
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'April Duck']

# %%
nephews.extend(['May Duck', 'Daisy Duck'])

# %%
nephews
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck']

# %%
ducks = nephews + ['Donald Duck', 'Daisy Duck']

# %%
ducks
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'Donald Duck',
#  'Daisy Duck']

# %%
ducks.insert(0, 'Scrooge McDuck')

# %%
ducks
# Out:
# ['Scrooge McDuck',
#  'Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'Donald Duck',
#  'Daisy Duck']

# %%
ducks
# Out:
# ['Scrooge McDuck',
#  'Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'Donald Duck',
#  'Daisy Duck']

# %%
del ducks[0]

# %%
ducks
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'Donald Duck',
#  'Daisy Duck']

# %%
ducks
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'Donald Duck',
#  'Daisy Duck']

# %%
ducks.remove('Donald Duck')

# %%
ducks
# Out:
# ['Huey Duck',
#  'Dewey Duck',
#  'Louie Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'April Duck',
#  'May Duck',
#  'Daisy Duck',
#  'Daisy Duck']

# %%
ducks.sort()

# %%
ducks
# Out:
# ['April Duck',
#  'April Duck',
#  'Daisy Duck',
#  'Daisy Duck',
#  'Daisy Duck',
#  'Dewey Duck',
#  'Huey Duck',
#  'Louie Duck',
#  'May Duck',
#  'May Duck']

# %%
reverse_ducks = sorted(ducks, reverse=True)

# %%
ducks
# Out:
# ['April Duck',
#  'April Duck',
#  'Daisy Duck',
#  'Daisy Duck',
#  'Daisy Duck',
#  'Dewey Duck',
#  'Huey Duck',
#  'Louie Duck',
#  'May Duck',
#  'May Duck']

# %%
reverse_ducks
# Out:
# ['May Duck',
#  'May Duck',
#  'Louie Duck',
#  'Huey Duck',
#  'Dewey Duck',
#  'Daisy Duck',
#  'Daisy Duck',
#  'Daisy Duck',
#  'April Duck',
#  'April Duck']

# %%
squares = [1,4,9,16,25,36,49]

# %%
#from start, slice me 2 tuple
squares[0:2]
# Out:
# [1, 4]

# %%
# from the start, slice me 4 now
squares[:4]
# Out:
# [1, 4, 9, 16]

# %%
# from the end, slice 3 reverse
squares[3:]
# Out:
# [16, 25, 36, 49]

# %%
# What will you get with this?
squares[:]
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
#from start, slice 7, skip 2
squares[0:7:2]
# Out:
# [1, 9, 25, 49]

# %%
# reverse slice 3  and slice 1
squares[-3:-1]
# Out:
# [25, 36]

# %%
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
# add two in between the tuple
squares[2:3] = ['four', 'nine']

# %%
squares
# Out:
# [1, 4, 'four', 'nine', 16, 25, 36, 49]

# %%
del squares[4:6]

# %%
squares
# Out:
# [1, 4, 'four', 'nine', 36, 49]

# %%
len([])
# Out:
# 0

# %%
integers = ('one', 'two','three', 'four')

# %%
integers
# Out:
# ('one', 'two', 'three', 'four')

# %%
integers[-1], integers[1:3]
# Out:
# ('four', ('two', 'three'))

# %%
#tuple does not support item assignment
integers[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 2
#       1 #tuple does not support item assignment
# ----> 2 integers[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
(a,b) = (1,2)

# %%
c,d = 3,4

# %%
for i, duck in enumerate(ducks):
    print(a,b,c)
# Out:
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3
# 1 2 3

# %%
'#data'
def three_args(a,b,c):
    print(a,b,c)

# %%
my_args = (1,2,3)

# %%
three_args(*my_args)
# Out:
# 1 2 3

# %%
g = 5
g = 6
print(g)
# Out:
# 6
